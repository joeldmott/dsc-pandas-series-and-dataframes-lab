# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands-on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# - Use the `.map()` and `.apply()` methods to apply a function to a pandas Series or DataFrame
# - Perform operations to change the structure of pandas DataFrames
# - Change the index of a pandas DataFrame
# - Change data types of columns in pandas DataFrames
#
# ## Let's get started!
#
# Import the file `'turnstile_180901.txt'`.

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Import the file 'turnstile_180901.txt'
df = pd.read_csv('turnstile_180901.txt')

# Print the number of rows and columns in df
print(df.shape)

# Print the first five rows of df
df.head()
# Out:
# (197625, 11)
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Rename all the columns to lower case:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197625 entries, 0 to 197624
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   197625 non-null  object
#  1   UNIT                                                                  197625 non-null  object
#  2   SCP                                                                   197625 non-null  object
#  3   STATION                                                               197625 non-null  object
#  4   LINENAME                                                              197625 non-null  object
#  5   DIVISION                                                              197625 non-null  object
# ...

# %%
df['DATE'].head()
# Out:
# 0    08/25/2018
# 1    08/25/2018
# 2    08/25/2018
# 3    08/25/2018
# 4    08/25/2018
# Name: DATE, dtype: object

# %%
# Rename all the columns to lower case
df.columns.str.lower()
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               '],
#       dtype='object')

# %% [markdown]
# Change the index to `'linename'`:

# %%
df['date'].head()
# Out:
# 0    08/25/2018
# 1    08/25/2018
# 2    08/25/2018
# 3    08/25/2018
# 4    08/25/2018
# Name: date, dtype: object

# %%
# Change the index to 'linename'
#df = df.set_index('linename')
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# Reset the index:

# %%
# Reset the index
df.reset_index()
# Out:
#          index    c/a  unit       scp        station linename division  \
# 0            0   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 1            1   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 2            2   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 3            3   A002  R051  02-00-00          59 ST  NQR456W      BMT
# 4            4   A002  R051  02-00-00          59 ST  NQR456W      BMT
# ...        ...    ...   ...       ...            ...      ...      ...
# 197620  197620  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197621  197621  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197622  197622  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197623  197623  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 197624  197624  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
#
#               date      time     desc  entries  \
# 0       08/25/2018  00:00:00  REGULAR  6736067
# ...

# %% [markdown]
# Create another column `'Num_Lines'` that is a count of how many lines pass through a station. Then sort your DataFrame by this column in descending order.
#
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
df['date'].head()
# Out:
# 0    08/25/2018
# 1    08/25/2018
# 2    08/25/2018
# 3    08/25/2018
# 4    08/25/2018
# Name: date, dtype: object

# %%
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
#df['num_lines'] = len(df['linename'])

#I'm not sure why the above returns '197625' for every value in 'linename', but I do understand why the code
# below works. It's defining the new column as (1) based off 'linename', (2) mapping something onto it, then
# (3) writing a lambda function that returns the string length of values in 'linename'.
df['num_lines'] = df['linename'].map(lambda n: len(n))

df = df.set_index('num_lines')
df.tail()
# Out:
#              c/a  unit       scp        station linename division        date  \
# num_lines
# 1          TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 1          TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 1          TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 1          TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
# 1          TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  08/31/2018
#
#                time     desc  entries  \
# num_lines
# 1          05:00:00  REGULAR     5554
# 1          09:00:00  REGULAR     5554
# 1          13:00:00  REGULAR     5554
# 1          17:00:00  REGULAR     5554
# 1          21:00:00  REGULAR     5554
#
#            exits
# num_lines
# 1                                                        348
# 1                                                        348
# 1                                                        348
# ...

# %% [markdown]
# Write a function to clean column names:

# %%
def clean(col_name):
    # Clean the column name in any way you want to. Hint: think back to str methods 
    #cleaned = df.columns.str.strip()
    #Whoa, that did something weird that made the next step throw a "truth error."
    cleaned = col_name.strip()
    return cleaned

# %%
# Use the above function to clean the column names
#df.columns.map(clean)
df.columns = [clean(col) for col in df.columns]

# %%
# Check to ensure the column names were cleaned
df.columns = df.columns.map(clean)
df.columns
# Out:
# Index(['c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time',
#        'desc', 'entries', 'exits', 'day_of_week'],
#       dtype='object')

# %% [markdown]
# - Change the data type of the `'date'` column to a date
# - Add a new column `'day_of_week'` that represents the day of the week

# %%
df['date'].head()
# Out:
# num_lines
# 7    08/25/2018
# 7    08/25/2018
# 7    08/25/2018
# 7    08/25/2018
# 7    08/25/2018
# Name: date, dtype: object

# %%
# Convert the data type of the 'date' column to a date

#pd.to_datetime(df['date'])
#df['date'] = pd.to_datetime(df['date'])
#Huh, I have no idea why that doesn't work since it's literally the solution. 
# However, I do remember that this doesn't always work and sometimes
# you have to do this other method:

#Now that I figured out I messed up on the above cleaning column name step, 
# I'm sure the above solution would've worked, but this also works:

df['date'] = pd.to_datetime(df['date'], format = '%m/%d/%Y')


# Add a new column 'day_of_week' that represents the day of the week 

#df['day_of_week'] = df['date'].map(lambda n: dt.day_name(n))

#Hmm, I guess lambda functions work more for base Python than 
# DataFrame stuff, so let's try a more df-friendly approach:
#df['day_of_week'] = df['date'].dt.day_name()
df['day_of_week'] = df['date'].dt.dayofweek

# %%
# Group the data by day of week and plot the sum of the numeric columns
grouped = df.groupby('day_of_week').sum()
grouped.plot(kind='barh')
plt.show()

# %% [markdown]
# - Remove the index of `grouped`
# - Print the first five rows of `grouped`

# %%
df.head()
# Out:
#             c/a  unit       scp station linename division       date  \
# num_lines
# 7          A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25
# 7          A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25
# 7          A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25
# 7          A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25
# 7          A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25
#
#                time     desc  entries    exits  day_of_week
# num_lines
# 7          00:00:00  REGULAR  6736067  2283184            5
# 7          04:00:00  REGULAR  6736087  2283188            5
# 7          08:00:00  REGULAR  6736105  2283229            5
# 7          12:00:00  REGULAR  6736180  2283314            5
# 7          16:00:00  REGULAR  6736349  2283384            5

# %%
grouped.head()
# Out:
#    day_of_week        entries         exits
# 0            0  1114237052454  911938153513
# 1            1  1143313287046  942230721477
# 2            2  1123655222441  920630864687
# 3            3  1122723988662  920691927110
# 4            4  1110224700078  906799065337

# %%
# Reset the index of grouped
#grouped = df.reset_index(grouped)
grouped = grouped.reset_index()

# Print the first five rows of grouped
#df['grouped'].head()
grouped.head()
# Out:
#    level_0  index  day_of_week        entries         exits
# 0        0      0            0  1114237052454  911938153513
# 1        1      1            1  1143313287046  942230721477
# 2        2      2            2  1123655222441  920630864687
# 3        3      3            3  1122723988662  920691927110
# 4        4      4            4  1110224700078  906799065337

# %% [markdown]
# Add a new column `'is_weekend'` that maps the `'day_of_week'` column using the dictionary `weekend_map`

# %%
# Use this dictionary to create a new column 
weekend_map = {0:False, 1:False, 2:False, 3:False, 4:False, 5:True, 6:True}

# Add a new column 'is_weekend' that maps the 'day_of_week' column using weekend_map
grouped['is_weekend'] = grouped['day_of_week'].map(weekend_map)

# %%
# Group the data by weekend/weekday and plot the sum of the numeric columns
wkend = grouped.groupby('is_weekend').sum()
wkend[['entries', 'exits']].plot(kind='barh')
plt.show()

# %% [markdown]
# Remove the `'c/a'` and `'scp'` columns.

# %%
# Remove the 'c/a' and 'scp' columns
df = df.drop('c/a', axis=1)
df = df.drop('scp', axis=1)
df.head(2)
# Out:
#            unit station linename division       date      time     desc  \
# num_lines
# 7          R051   59 ST  NQR456W      BMT 2018-08-25  00:00:00  REGULAR
# 7          R051   59 ST  NQR456W      BMT 2018-08-25  04:00:00  REGULAR
#
#            entries    exits  day_of_week
# num_lines
# 7          6736067  2283184            5
# 7          6736087  2283188            5

# %% [markdown]
# ## Analysis Question
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here 
'The graph legend order should be flipped to match the actual bars in the graph.' 

"Ah, and also the info is cumulative, so I guess that means it only shows the total amount of entries/exits,
"but that isn't really meaningful or interesting. Maybe putting the time of day or the stations in there
"would wind up with a more compelling show of data. So ultimately, what we did 
"here is more like a good starting point."

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup skills using Pandas.
